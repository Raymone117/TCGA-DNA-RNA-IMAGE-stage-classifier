# %%
import os
import json
import joblib
import numpy as np
import pandas as pd
from pathlib import Path
import flwr as fl

# ===== Configuration =====
SERVER = "192.168.1.217:8090"                     # Server address
FEATURES_CSV = r"C:\Users\mxjli\PyCharmMiscProject\final_results\features_test.csv"    # Test feature file
MODEL_PATH = r"C:\Users\mxjli\PyCharmMiscProject\final_results\stage_classifier.pkl"   # Trained RandomWalk model
SCALER_PATH = r"C:\Users\mxjli\PyCharmMiscProject\final_results\scaler.pkl"            # Scaler
FEATCOLS_PATH = r"C:\Users\mxjli\PyCharmMiscProject\final_results\feat_cols.pkl"       # Feature column file
MODALITY = "WSI"                              # Modality name
N_CLASSES = 4                                 # Number of classes
WEIGHT = 1.0                                  # Weight for federated aggregation

# ===== Load model, scaler, and feature columns =====
print("[INFO] Loading model, scaler, and feature columns...")
clf = joblib.load(MODEL_PATH)
scaler = joblib.load(SCALER_PATH)
feat_cols = joblib.load(FEATCOLS_PATH)

# ===== Load test features =====
df = pd.read_csv(FEATURES_CSV)
print(f"[INFO] Loaded test set with {len(df)} samples.")

# ===== Check feature completeness =====
if not all(col in df.columns for col in feat_cols):
    missing = [c for c in feat_cols if c not in df.columns]
    raise ValueError(f"❌ Missing feature columns: {missing}")

# Extract and standardize features
X = df[feat_cols].values
X_scaled = scaler.transform(X)

# ===== Extract patient IDs =====
def to_patient_id(path: str) -> str:
    """Extract the first three parts of TCGA ID from file path"""
    stem = Path(path).stem
    return "-".join(stem.split("-")[:3])

if "path" in df.columns:
    ids = [to_patient_id(p) for p in df["path"]]
else:
    ids = [f"sample_{i}" for i in range(len(df))]

print(f"[INFO] Prepared {len(ids)} samples for prediction.")
print("[DEBUG] First 5 patient IDs:", ids[:5])

# ===== Define client class =====
class RandomWalkClient(fl.client.NumPyClient):
    def __init__(self, clf, X, ids, modality, weight):
        self.clf = clf
        self.X = X
        self.ids = ids
        self.modality = modality
        self.weight = weight

    # Required methods for federated learning
    def get_parameters(self, config):
        return []

    def fit(self, parameters, config):
        return [], 0, {}

    def evaluate(self, parameters, config):
        task = config.get("task", "")
        metrics = {}

        if task == "predict":
            print(f"[INFO] Starting prediction for {len(self.ids)} samples...")
            probs_all = self.clf.predict_proba(self.X)
            rows = []

            for pid, probs in zip(self.ids, probs_all):
                probs = np.clip(probs.astype(float), 1e-9, 1.0)
                probs = probs / probs.sum()
                row = {
                    "patient_id": pid,
                    "probs": probs.tolist(),
                    "modality": self.modality,
                    "weight": self.weight
                }
                print(f"[PREDICT] {pid}: predicted class = {np.argmax(probs)}, probs = {probs}")
                rows.append(row)

            # Package prediction results as JSON to send to server
            metrics = {"preds_json": json.dumps(rows)}
            print(f"[INFO] Prediction complete. Sending {len(rows)} results to server.")

        return 0.0, len(self.ids), metrics


# ===== Start client =====
if __name__ == "__main__":
    print(f"[START] Connecting to server {SERVER} ...")
    fl.client.start_numpy_client(
        server_address=SERVER,
        client=RandomWalkClient(clf, X_scaled, ids, MODALITY, WEIGHT)
    )
    print("[DONE] Client execution finished.")
# Out:
# [INFO] Loading model, scaler, and feature columns...
# C:\Users\mxjli\PyCharmMiscProject\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# WARNING :   DEPRECATED FEATURE: flwr.client.start_numpy_client() is deprecated.
# 	Instead, use `flwr.client.start_client()` by ensuring you first call the `.to_client()` method as shown below:
# 	flwr.client.start_client(
# 		server_address='<IP>:<PORT>',
# 		client=FlowerClient().to_client(), # <-- where FlowerClient is of type flwr.client.NumPyClient object
# 	)
# 	Using `start_numpy_client()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# WARNING :   DEPRECATED FEATURE: flwr.client.start_client() is deprecated.
# 	Instead, use the `flower-supernode` CLI command to start a SuperNode as shown below:
#
# 		$ flower-supernode --insecure --superlink='<IP>:<PORT>'
#
# 	To view all available options, run:
#
# 		$ flower-supernode --help
#
# 	Using `start_client()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# INFO :
# INFO :      Received: get_parameters message 18ebbe29-ac2b-4c36-8036-967e4f6bee28
# INFO :      Sent reply
# INFO :
# INFO :      Received: evaluate message b939d5e2-44f2-443c-aac0-9dfaba7e071f
# C:\Users\mxjli\PyCharmMiscProject\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# INFO :      Sent reply
# INFO :
# INFO :      Received: reconnect message 6494be39-0c7a-4520-8fc2-e38a6a16cc0c
# INFO :      Disconnect and shut down
# [INFO] Loaded test set with 28 samples.
# [INFO] Prepared 28 samples for prediction.
# [DEBUG] First 5 patient IDs: ['TCGA-A1-A0SN', 'TCGA-A2-A04N', 'TCGA-A2-A04R', 'TCGA-A2-A0T1', 'TCGA-A2-A0T3']
# [START] Connecting to server 192.168.1.217:8090 ...
# [INFO] Starting prediction for 28 samples...
# [PREDICT] TCGA-A1-A0SN: predicted class = 0, probs = [0.39691204 0.36940565 0.17028783 0.06339449]
# [PREDICT] TCGA-A2-A04N: predicted class = 0, probs = [0.36131724 0.29066678 0.16045097 0.18756501]
# [PREDICT] TCGA-A2-A04R: predicted class = 2, probs = [0.3109928  0.31284397 0.36905542 0.00710781]
# [PREDICT] TCGA-A2-A0T1: predicted class = 1, probs = [0.39472591 0.42531656 0.15176075 0.02819679]
# [PREDICT] TCGA-A2-A0T3: predicted class = 3, probs = [0.2237709  0.29157861 0.15906819 0.32558229]
# [PREDICT] TCGA-A2-A0YM: predicted class = 1, probs = [0.2646154  0.42885837 0.26515086 0.04137537]
# [PREDICT] TCGA-A2-A3XZ: predicted class = 0, probs = [0.48621126 0.3594942  0.11809452 0.03620001]
# [PREDICT] TCGA-A7-A426: predicted class = 1, probs = [0.16658037 0.64853705 0.13943606 0.04544652]
# [PREDICT] TCGA-A8-A06T: predicted class = 1, probs = [0.18176509 0.37504336 0.25054957 0.19264199]
# [PREDICT] TCGA-A8-A06U: predicted class = 0, probs = [0.42896416 0.28087801 0.20550576 0.08465208]
# [PREDICT] TCGA-A8-A07F: predicted class = 3, probs = [0.18637914 0.22614148 0.25491505 0.33256434]
# [PREDICT] TCGA-A8-A07L: predicted class = 0, probs = [0.35958181 0.27372332 0.185503   0.18119187]
# [PREDICT] TCGA-A8-A082: predicted class = 1, probs = [0.12462213 0.5148635  0.13646867 0.2240457 ]
# [PREDICT] TCGA-A8-A086: predicted class = 2, probs = [0.14184435 0.21455654 0.33991866 0.30368045]
# [PREDICT] TCGA-A8-A09K: predicted class = 3, probs = [0.25951168 0.25859221 0.20376442 0.2781317 ]
# [PREDICT] TCGA-A8-A09Q: predicted class = 1, probs = [0.1569935  0.63396672 0.16502362 0.04401615]
# [PREDICT] TCGA-A8-A09X: predicted class = 3, probs = [0.08855837 0.1158898  0.21510514 0.58044669]
# [PREDICT] TCGA-AC-A2B8: predicted class = 1, probs = [0.20421493 0.54155001 0.2069272  0.04730787]
# [PREDICT] TCGA-AR-A24H: predicted class = 0, probs = [0.45108244 0.32617651 0.20844623 0.01429482]
# [PREDICT] TCGA-B6-A0WZ: predicted class = 1, probs = [0.20827453 0.58800366 0.14186085 0.06186096]
# [PREDICT] TCGA-E2-A14U: predicted class = 1, probs = [0.2914901  0.43914214 0.23639184 0.03297592]
# [PREDICT] TCGA-E2-A1II: predicted class = 1, probs = [0.25512701 0.42118956 0.30733791 0.01634552]
# [PREDICT] TCGA-E9-A1NC: predicted class = 2, probs = [0.12714485 0.30558995 0.37592236 0.19134284]
# [PREDICT] TCGA-E9-A1ND: predicted class = 1, probs = [0.11432027 0.52061362 0.23379574 0.13127037]
# [PREDICT] TCGA-E9-A54Y: predicted class = 1, probs = [0.10392871 0.50560277 0.31651926 0.07394925]
# [PREDICT] TCGA-PL-A8LX: predicted class = 3, probs = [0.2226255  0.1742084  0.20682051 0.39634558]
# [PREDICT] TCGA-S3-A6ZF: predicted class = 1, probs = [0.26578231 0.40717745 0.32418949 0.00285075]
# [PREDICT] TCGA-WT-AB41: predicted class = 1, probs = [0.17657684 0.50019295 0.21441069 0.10881952]
# [INFO] Prediction complete. Sending 28 results to server.
# [DONE] Client execution finished.
